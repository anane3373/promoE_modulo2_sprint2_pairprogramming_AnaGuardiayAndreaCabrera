# %% [markdown]
# # LIMPIEZA 2 17/08

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
pd.options.display.max_columns = None

# %%
df = pd.read_csv("data/pair1_bank_additional_full.csv", index_col = 0)
df
# Out:
#        index   age          job  marital            education  default  \
# 0          0  56.0    housemaid  married                  NaN      0.0
# 1          1   NaN     services  married                  NaN      NaN
# 2          2  37.0     services  married          high.school      0.0
# 3          3  40.0          NaN  married             basic.6y      0.0
# 4          4  56.0     services      NaN                  NaN      0.0
# ...      ...   ...          ...      ...                  ...      ...
# 41181  41183  73.0      retired  married  professional.course      0.0
# 41182  41184  46.0  blue-collar  married  professional.course      0.0
# 41183  41185  56.0      retired  married    university.degree      0.0
# 41184  41186  44.0   technician  married  professional.course      0.0
# 41185  41187  74.0      retired  married  professional.course      0.0
#
#        housing  loan    contact  duration  campaign  pdays  previous  \
# 0          0.0   0.0  telephone       261       1.0    999         0
# 1          0.0   NaN  telephone       149       1.0    999         0
# 2          1.0   0.0  telephone       226       1.0    999         0
# 3          0.0   0.0  telephone       151       1.0    999         0
# 4          0.0   1.0  telephone       307       1.0    999         0
# ...        ...   ...        ...       ...       ...    ...       ...
# 41181      1.0   0.0   cellular       334       1.0    999         0
# 41182      0.0   0.0   cellular       383       1.0    999         0
# 41183      1.0   0.0   cellular       189       2.0    999         0
# 41184      0.0   0.0   cellular       442       1.0    999         0
# 41185      1.0   0.0   cellular       239       3.0    999         1
#
#           poutcome  emp,var,rate  cons,price,idx  cons,conf,idx  euribor3m  \
# 0      NONEXISTENT           NaN          93.994          -36.4      4.857
# 1      NONEXISTENT           NaN          93.994          -36.4      4.857
# 2      NONEXISTENT           1.1          93.994          -36.4      4.857
# 3      NONEXISTENT           1.1          93.994          -36.4      4.857
# 4      NONEXISTENT           1.1             NaN          -36.4      4.857
# ...            ...           ...             ...            ...        ...
# 41181  NONEXISTENT          -1.1          94.767          -50.8      1.028
# 41182  NONEXISTENT          -1.1             NaN          -50.8      1.028
# 41183  NONEXISTENT           NaN          94.767          -50.8      1.028
# 41184  NONEXISTENT          -1.1          94.767          -50.8      1.028
# 41185      FAILURE           NaN          94.767          -50.8      1.028
#
#        nr,employed    y  month_day_week
# 0           5191.0   no  ['may', 'mon']
# 1           5191.0   no  ['may', 'mon']
# 2           5191.0  NaN  ['may', 'mon']
# 3           5191.0   no  ['may', 'mon']
# 4           5191.0   no  ['may', 'mon']
# ...            ...  ...             ...
# 41181       4963.6  yes  ['nov', 'fri']
# 41182       4963.6   no  ['nov', 'fri']
# 41183       4963.6   no  ['nov', 'fri']
# 41184       4963.6  NaN  ['nov', 'fri']
# 41185       4963.6   no  ['nov', 'fri']
#
# [41186 rows x 21 columns]

# %% [markdown]
# 1. Columnas loan, housing y default: estas columnas contienen valores únicos de 0 y 1. Esto puede parecer poco intuitivo a la hora de la extracción de conclusiones y en las visualizaciones. El objetivo de este ejercicio es que cambies los valores númericos por "Si" y "No". A que corresponde cada uno de los valores lo tenéis en el pair de Limpieza I.

# %%
df["loan"].unique()
# Out:
# array([ 0., nan,  1.])

# %%
df["loan_modificado"] = pd.cut(df["loan"], 2, labels = ["sí", "no"])

df
# Out:
#        index   age          job  marital            education  default  \
# 0          0  56.0    housemaid  married                  NaN      0.0
# 1          1   NaN     services  married                  NaN      NaN
# 2          2  37.0     services  married          high.school      0.0
# 3          3  40.0          NaN  married             basic.6y      0.0
# 4          4  56.0     services      NaN                  NaN      0.0
# ...      ...   ...          ...      ...                  ...      ...
# 41181  41183  73.0      retired  married  professional.course      0.0
# 41182  41184  46.0  blue-collar  married  professional.course      0.0
# 41183  41185  56.0      retired  married    university.degree      0.0
# 41184  41186  44.0   technician  married  professional.course      0.0
# 41185  41187  74.0      retired  married  professional.course      0.0
#
#        housing  loan    contact  duration  campaign  pdays  previous  \
# 0          0.0   0.0  telephone       261       1.0    999         0
# 1          0.0   NaN  telephone       149       1.0    999         0
# 2          1.0   0.0  telephone       226       1.0    999         0
# 3          0.0   0.0  telephone       151       1.0    999         0
# 4          0.0   1.0  telephone       307       1.0    999         0
# ...        ...   ...        ...       ...       ...    ...       ...
# 41181      1.0   0.0   cellular       334       1.0    999         0
# 41182      0.0   0.0   cellular       383       1.0    999         0
# 41183      1.0   0.0   cellular       189       2.0    999         0
# 41184      0.0   0.0   cellular       442       1.0    999         0
# 41185      1.0   0.0   cellular       239       3.0    999         1
#
#           poutcome  emp,var,rate  cons,price,idx  cons,conf,idx  euribor3m  \
# 0      NONEXISTENT           NaN          93.994          -36.4      4.857
# 1      NONEXISTENT           NaN          93.994          -36.4      4.857
# 2      NONEXISTENT           1.1          93.994          -36.4      4.857
# 3      NONEXISTENT           1.1          93.994          -36.4      4.857
# 4      NONEXISTENT           1.1             NaN          -36.4      4.857
# ...            ...           ...             ...            ...        ...
# 41181  NONEXISTENT          -1.1          94.767          -50.8      1.028
# 41182  NONEXISTENT          -1.1             NaN          -50.8      1.028
# 41183  NONEXISTENT           NaN          94.767          -50.8      1.028
# 41184  NONEXISTENT          -1.1          94.767          -50.8      1.028
# 41185      FAILURE           NaN          94.767          -50.8      1.028
#
#        nr,employed    y  month_day_week loan_modificado
# 0           5191.0   no  ['may', 'mon']              sí
# 1           5191.0   no  ['may', 'mon']             NaN
# 2           5191.0  NaN  ['may', 'mon']              sí
# 3           5191.0   no  ['may', 'mon']              sí
# 4           5191.0   no  ['may', 'mon']              no
# ...            ...  ...             ...             ...
# 41181       4963.6  yes  ['nov', 'fri']              sí
# 41182       4963.6   no  ['nov', 'fri']              sí
# 41183       4963.6   no  ['nov', 'fri']              sí
# 41184       4963.6  NaN  ['nov', 'fri']              sí
# 41185       4963.6   no  ['nov', 'fri']              sí
#
# [41186 rows x 22 columns]

# %%
df["housing_modificado"] = pd.cut(df["housing"], 2, labels = ["sí", "no"])

df
# Out:
#        index   age          job  marital            education  default  \
# 0          0  56.0    housemaid  married                  NaN      0.0
# 1          1   NaN     services  married                  NaN      NaN
# 2          2  37.0     services  married          high.school      0.0
# 3          3  40.0          NaN  married             basic.6y      0.0
# 4          4  56.0     services      NaN                  NaN      0.0
# ...      ...   ...          ...      ...                  ...      ...
# 41181  41183  73.0      retired  married  professional.course      0.0
# 41182  41184  46.0  blue-collar  married  professional.course      0.0
# 41183  41185  56.0      retired  married    university.degree      0.0
# 41184  41186  44.0   technician  married  professional.course      0.0
# 41185  41187  74.0      retired  married  professional.course      0.0
#
#        housing  loan    contact  duration  campaign  pdays  previous  \
# 0          0.0   0.0  telephone       261       1.0    999         0
# 1          0.0   NaN  telephone       149       1.0    999         0
# 2          1.0   0.0  telephone       226       1.0    999         0
# 3          0.0   0.0  telephone       151       1.0    999         0
# 4          0.0   1.0  telephone       307       1.0    999         0
# ...        ...   ...        ...       ...       ...    ...       ...
# 41181      1.0   0.0   cellular       334       1.0    999         0
# 41182      0.0   0.0   cellular       383       1.0    999         0
# 41183      1.0   0.0   cellular       189       2.0    999         0
# 41184      0.0   0.0   cellular       442       1.0    999         0
# 41185      1.0   0.0   cellular       239       3.0    999         1
#
#           poutcome  emp,var,rate  cons,price,idx  cons,conf,idx  euribor3m  \
# 0      NONEXISTENT           NaN          93.994          -36.4      4.857
# 1      NONEXISTENT           NaN          93.994          -36.4      4.857
# 2      NONEXISTENT           1.1          93.994          -36.4      4.857
# 3      NONEXISTENT           1.1          93.994          -36.4      4.857
# 4      NONEXISTENT           1.1             NaN          -36.4      4.857
# ...            ...           ...             ...            ...        ...
# 41181  NONEXISTENT          -1.1          94.767          -50.8      1.028
# 41182  NONEXISTENT          -1.1             NaN          -50.8      1.028
# 41183  NONEXISTENT           NaN          94.767          -50.8      1.028
# 41184  NONEXISTENT          -1.1          94.767          -50.8      1.028
# 41185      FAILURE           NaN          94.767          -50.8      1.028
#
#        nr,employed    y  month_day_week loan_modificado housing_modificado
# 0           5191.0   no  ['may', 'mon']              sí                 sí
# 1           5191.0   no  ['may', 'mon']             NaN                 sí
# 2           5191.0  NaN  ['may', 'mon']              sí                 no
# 3           5191.0   no  ['may', 'mon']              sí                 sí
# 4           5191.0   no  ['may', 'mon']              no                 sí
# ...            ...  ...             ...             ...                ...
# 41181       4963.6  yes  ['nov', 'fri']              sí                 no
# 41182       4963.6   no  ['nov', 'fri']              sí                 sí
# 41183       4963.6   no  ['nov', 'fri']              sí                 no
# 41184       4963.6  NaN  ['nov', 'fri']              sí                 sí
# 41185       4963.6   no  ['nov', 'fri']              sí                 no
#
# [41186 rows x 23 columns]

# %%
df["default_modificado"] = pd.cut(df["default"], 2, labels = ["sí", "no"])

df
# Out:
#        index   age          job  marital            education  default  \
# 0          0  56.0    housemaid  married                  NaN      0.0
# 1          1   NaN     services  married                  NaN      NaN
# 2          2  37.0     services  married          high.school      0.0
# 3          3  40.0          NaN  married             basic.6y      0.0
# 4          4  56.0     services      NaN                  NaN      0.0
# ...      ...   ...          ...      ...                  ...      ...
# 41181  41183  73.0      retired  married  professional.course      0.0
# 41182  41184  46.0  blue-collar  married  professional.course      0.0
# 41183  41185  56.0      retired  married    university.degree      0.0
# 41184  41186  44.0   technician  married  professional.course      0.0
# 41185  41187  74.0      retired  married  professional.course      0.0
#
#        housing  loan    contact  duration  campaign  pdays  previous  \
# 0          0.0   0.0  telephone       261       1.0    999         0
# 1          0.0   NaN  telephone       149       1.0    999         0
# 2          1.0   0.0  telephone       226       1.0    999         0
# 3          0.0   0.0  telephone       151       1.0    999         0
# 4          0.0   1.0  telephone       307       1.0    999         0
# ...        ...   ...        ...       ...       ...    ...       ...
# 41181      1.0   0.0   cellular       334       1.0    999         0
# 41182      0.0   0.0   cellular       383       1.0    999         0
# 41183      1.0   0.0   cellular       189       2.0    999         0
# 41184      0.0   0.0   cellular       442       1.0    999         0
# 41185      1.0   0.0   cellular       239       3.0    999         1
#
#           poutcome  emp,var,rate  cons,price,idx  cons,conf,idx  euribor3m  \
# 0      NONEXISTENT           NaN          93.994          -36.4      4.857
# 1      NONEXISTENT           NaN          93.994          -36.4      4.857
# 2      NONEXISTENT           1.1          93.994          -36.4      4.857
# 3      NONEXISTENT           1.1          93.994          -36.4      4.857
# 4      NONEXISTENT           1.1             NaN          -36.4      4.857
# ...            ...           ...             ...            ...        ...
# 41181  NONEXISTENT          -1.1          94.767          -50.8      1.028
# 41182  NONEXISTENT          -1.1             NaN          -50.8      1.028
# 41183  NONEXISTENT           NaN          94.767          -50.8      1.028
# 41184  NONEXISTENT          -1.1          94.767          -50.8      1.028
# 41185      FAILURE           NaN          94.767          -50.8      1.028
#
#        nr,employed    y  month_day_week loan_modificado housing_modificado  \
# 0           5191.0   no  ['may', 'mon']              sí                 sí
# 1           5191.0   no  ['may', 'mon']             NaN                 sí
# 2           5191.0  NaN  ['may', 'mon']              sí                 no
# 3           5191.0   no  ['may', 'mon']              sí                 sí
# 4           5191.0   no  ['may', 'mon']              no                 sí
# ...            ...  ...             ...             ...                ...
# 41181       4963.6  yes  ['nov', 'fri']              sí                 no
# 41182       4963.6   no  ['nov', 'fri']              sí                 sí
# 41183       4963.6   no  ['nov', 'fri']              sí                 no
# 41184       4963.6  NaN  ['nov', 'fri']              sí                 sí
# 41185       4963.6   no  ['nov', 'fri']              sí                 no
#
#       default_modificado
# 0                     sí
# 1                    NaN
# 2                     sí
# 3                     sí
# 4                     sí
# ...                  ...
# 41181                 sí
# 41182                 sí
# 41183                 sí
# 41184                 sí
# 41185                 sí
#
# [41186 rows x 24 columns]

# %% [markdown]
# 2. Para la columna de education, si nos fijamos en sus valores únicos veremos que tenemos puntos. El objetivo de este ejercicio es que quitéis los puntos de esos valores y los reemplacéis por espacios.

# %%
df["education"].unique()
# Out:
# array([nan, 'high.school', 'basic.6y', 'basic.9y', 'professional.course',
#        'basic.4y', 'university.degree', 'illiterate'], dtype=object)

# %%
df['education'] = df['education'].str.replace('.', ' ')
df
# Out:
#        index   age          job  marital            education  default  \
# 0          0  56.0    housemaid  married                  NaN      0.0
# 1          1   NaN     services  married                  NaN      NaN
# 2          2  37.0     services  married          high school      0.0
# 3          3  40.0          NaN  married             basic 6y      0.0
# 4          4  56.0     services      NaN                  NaN      0.0
# ...      ...   ...          ...      ...                  ...      ...
# 41181  41183  73.0      retired  married  professional course      0.0
# 41182  41184  46.0  blue-collar  married  professional course      0.0
# 41183  41185  56.0      retired  married    university degree      0.0
# 41184  41186  44.0   technician  married  professional course      0.0
# 41185  41187  74.0      retired  married  professional course      0.0
#
#        housing  loan    contact  duration  campaign  pdays  previous  \
# 0          0.0   0.0  telephone       261       1.0    999         0
# 1          0.0   NaN  telephone       149       1.0    999         0
# 2          1.0   0.0  telephone       226       1.0    999         0
# 3          0.0   0.0  telephone       151       1.0    999         0
# 4          0.0   1.0  telephone       307       1.0    999         0
# ...        ...   ...        ...       ...       ...    ...       ...
# 41181      1.0   0.0   cellular       334       1.0    999         0
# 41182      0.0   0.0   cellular       383       1.0    999         0
# 41183      1.0   0.0   cellular       189       2.0    999         0
# 41184      0.0   0.0   cellular       442       1.0    999         0
# 41185      1.0   0.0   cellular       239       3.0    999         1
#
#           poutcome  emp,var,rate  cons,price,idx  cons,conf,idx  euribor3m  \
# 0      NONEXISTENT           NaN          93.994          -36.4      4.857
# 1      NONEXISTENT           NaN          93.994          -36.4      4.857
# 2      NONEXISTENT           1.1          93.994          -36.4      4.857
# 3      NONEXISTENT           1.1          93.994          -36.4      4.857
# 4      NONEXISTENT           1.1             NaN          -36.4      4.857
# ...            ...           ...             ...            ...        ...
# 41181  NONEXISTENT          -1.1          94.767          -50.8      1.028
# 41182  NONEXISTENT          -1.1             NaN          -50.8      1.028
# 41183  NONEXISTENT           NaN          94.767          -50.8      1.028
# 41184  NONEXISTENT          -1.1          94.767          -50.8      1.028
# 41185      FAILURE           NaN          94.767          -50.8      1.028
#
#        nr,employed    y  month_day_week loan_modificado housing_modificado  \
# 0           5191.0   no  ['may', 'mon']              sí                 sí
# 1           5191.0   no  ['may', 'mon']             NaN                 sí
# 2           5191.0  NaN  ['may', 'mon']              sí                 no
# 3           5191.0   no  ['may', 'mon']              sí                 sí
# 4           5191.0   no  ['may', 'mon']              no                 sí
# ...            ...  ...             ...             ...                ...
# 41181       4963.6  yes  ['nov', 'fri']              sí                 no
# 41182       4963.6   no  ['nov', 'fri']              sí                 sí
# 41183       4963.6   no  ['nov', 'fri']              sí                 no
# 41184       4963.6  NaN  ['nov', 'fri']              sí                 sí
# 41185       4963.6   no  ['nov', 'fri']              sí                 no
#
#       default_modificado
# 0                     sí
# 1                    NaN
# 2                     sí
# 3                     sí
# 4                     sí
# ...                  ...
# 41181                 sí
# 41182                 sí
# 41183                 sí
# 41184                 sí
# 41185                 sí
#
# [41186 rows x 24 columns]

# %% [markdown]
# 3. Para la columna job, hay un valor único que está abreviado (admin.), cambiad la abreviatura por el nombre completo.

# %%
df["job"].unique()
# Out:
# array(['housemaid', 'services', nan, 'admin.', 'blue-collar',
#        'technician', 'retired', 'management', 'unemployed',
#        'self-employed', 'entrepreneur', 'student'], dtype=object)

# %%
df['job'] = df['job'].str.replace('admin.', 'administrator', regex = True)

# %%
df["job"].unique()
# Out:
# array(['housemaid', 'services', nan, 'administrator', 'blue-collar',
#        'technician', 'retired', 'management', 'unemployed',
#        'self-employed', 'entrepreneur', 'student'], dtype=object)

# %% [markdown]
# 4. La columna month_day_week tiene una lista que contiene información muy diferente. El objetivo de este ejercicio es separar esta columna en dos nuevas, donde tengamos los meses en una columna y los días de la semana en otra.

# %%
df["month_day_week"].unique()
# Out:
# array(["['may', 'mon']", "['may', 'tue']", "['may', 'wed']",
#        "['may', 'thu']", "['may', 'fri']", "['jun', 'mon']",
#        "['jun', 'tue']", "['jun', 'wed']", "['jun', 'thu']",
#        "['jun', 'fri']", "['jul', 'tue']", "['jul', 'wed']",
#        "['jul', 'thu']", "['jul', 'fri']", "['jul', 'mon']",
#        "['aug', 'mon']", "['aug', 'tue']", "['aug', 'wed']",
#        "['aug', 'thu']", "['aug', 'fri']", "['oct', 'fri']",
#        "['oct', 'mon']", "['oct', 'tue']", "['oct', 'wed']",
#        "['oct', 'thu']", "['nov', 'mon']", "['nov', 'tue']",
#        "['nov', 'wed']", "['nov', 'thu']", "['nov', 'fri']",
#        "['dec', 'mon']", "['dec', 'wed']", "['dec', 'thu']",
#        "['dec', 'fri']", "['dec', 'tue']", "['mar', 'mon']",
#        "['mar', 'tue']", "['mar', 'wed']", "['mar', 'thu']",
#        "['mar', 'fri']", "['apr', 'wed']", "['apr', 'thu']",
#        "['apr', 'fri']", "['apr', 'mon']", "['apr', 'tue']",
#        "['sep', 'tue']", "['sep', 'wed']", "['sep', 'thu']",
#        "['sep', 'fri']", "['sep', 'mon']"], dtype=object)

# %% [markdown]
# ['may', 'mon']
#
# [   :   0
# '   :   1
# m   :   2
# a   :   3
# y   :   4
# '   :   5
# ,   :   6
#     :   7
# '   :   8
# m   :   9
# o   :   10
# n   :   11
# '   :   12
# ]   :   13

# %%
def obtain_month(row):
    """Obtiene el mes desde un str. Ejemplo: "['may', 'mon']". Se queda con los carácteres 'may'

    Args:
        row (str): Conjunto de mes y día

    Returns:
        str: Mes
    """
    return row[2:5]

# %%
df["month"] = df["month_day_week"].apply(obtain_month)

# %%
def obtain_day(row):
    """Obtiene el día de la semana desde un str. Ejemplo: "['may', 'mon']". Se queda con los carácteres 'mon'.

    Args:
        row (str): Conjunto de mes y día

    Returns:
        str: Día de la semana
    """
    return row[9:12]

# %%
df["day"] = df["month_day_week"].apply(obtain_day)

# %%
df[["month_day_week","month","day"]].head()
# Out:
#    month_day_week month  day
# 0  ['may', 'mon']   may  mon
# 1  ['may', 'mon']   may  mon
# 2  ['may', 'mon']   may  mon
# 3  ['may', 'mon']   may  mon
# 4  ['may', 'mon']   may  mon

# %%
df["month_day_week"][0][2:5]
# Out:
# 'may'

# %%
df["month_day_week"][0][9:12]
# Out:
# 'mon'

# %%
df.head(8)
# Out:
#    index   age            job  marital            education  default  housing  \
# 0      0  56.0      housemaid  married                  NaN      0.0      0.0
# 1      1   NaN       services  married                  NaN      NaN      0.0
# 2      2  37.0       services  married          high school      0.0      1.0
# 3      3  40.0            NaN  married             basic 6y      0.0      0.0
# 4      4  56.0       services      NaN                  NaN      0.0      0.0
# 5      5  45.0       services  married             basic 9y      NaN      0.0
# 6      6  59.0  administrator  married  professional course      0.0      0.0
# 7      7  41.0    blue-collar  married                  NaN      NaN      0.0
#
#    loan    contact  duration  campaign  pdays  previous     poutcome  \
# 0   0.0  telephone       261       1.0    999         0  NONEXISTENT
# 1   NaN  telephone       149       1.0    999         0  NONEXISTENT
# 2   0.0  telephone       226       1.0    999         0  NONEXISTENT
# 3   0.0  telephone       151       1.0    999         0  NONEXISTENT
# 4   1.0  telephone       307       1.0    999         0  NONEXISTENT
# 5   0.0  telephone       198       1.0    999         0  NONEXISTENT
# 6   0.0  telephone       139       1.0    999         0  NONEXISTENT
# 7   0.0  telephone       217       1.0    999         0  NONEXISTENT
#
#    emp,var,rate  cons,price,idx  cons,conf,idx  euribor3m  nr,employed    y  \
# 0           NaN          93.994          -36.4      4.857       5191.0   no
# 1           NaN          93.994          -36.4      4.857       5191.0   no
# 2           1.1          93.994          -36.4      4.857       5191.0  NaN
# 3           1.1          93.994          -36.4      4.857       5191.0   no
# 4           1.1             NaN          -36.4      4.857       5191.0   no
# 5           1.1          93.994          -36.4      4.857       5191.0  NaN
# 6           1.1             NaN          -36.4      4.857       5191.0   no
# 7           1.1          93.994          -36.4      4.857       5191.0   no
#
#    month_day_week loan_modificado housing_modificado default_modificado month  \
# 0  ['may', 'mon']              sí                 sí                 sí   may
# 1  ['may', 'mon']             NaN                 sí                NaN   may
# 2  ['may', 'mon']              sí                 no                 sí   may
# 3  ['may', 'mon']              sí                 sí                 sí   may
# 4  ['may', 'mon']              no                 sí                 sí   may
# 5  ['may', 'mon']              sí                 sí                NaN   may
# 6  ['may', 'mon']              sí                 sí                 sí   may
# 7  ['may', 'mon']              sí                 sí                NaN   may
#
#    day
# 0  mon
# 1  mon
# 2  mon
# 3  mon
# 4  mon
# 5  mon
# 6  mon
# 7  mon

# %% [markdown]
# 5. Guarda el csv con las columnas limpias para seguir trabajando con este dataframe limpio.

# %%
df.to_csv("data/pair2_bank_additional_full.csv")
